# %%
from selenium import webdriver

# %%
driver = webdriver.Firefox(executable_path = 'geckodriver.exe')
driver
# Out:
# <selenium.webdriver.firefox.webdriver.WebDriver (session="f5e3d6b6-167c-4108-8a4c-71d65c337803")>

# %%
driver.get('https://www.codingninjas.com/')

# %%
driver.title
# Out:
# 'Coding Ninjas – Learn coding online at India’s best coding institute'

# %%
driver.back()

# %%
driver.forward()

# %%
driver.back()

# %%
driver.save_screenshot('test_shot.png')
# Out:
# True

# %%
driver.back()

# %%
driver.page_source
# Out:
# '<html lang="en"><head>\n    <meta charset="utf-8">\n    <title>Coding Ninjas – Learn coding online at India’s best coding institute</title>\n\n    <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">\n    <meta name="title" content="Coding Ninjas – Learn coding online at India’s best coding institute">\n    <meta property="og:title" content="Coding Ninjas – Learn coding online at India’s best coding institute">\n    <meta name="description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:image" content="https://files.codingninjas.in/0000000000000723.jpg">\n\n    <base href="/">\n    <meta name="viewport" content="width=dev
# ...

# %%
driver.back()

# %%
driver.forward()

# %%
reg_btn = driver.find_element_by_partial_link_text('Courses')
reg_btn.click()

# %%
driver.back()

# %%
driver.forward()

# %%
reg_btn = driver.find_element_by_partial_link_text('Inter')
reg_btn.click()

# %%
driver.back()

# %%
driver.forward()

# %%
driver.back()

# %%
driver.maximize_window()

# %%
driver.close()

# %%
driver = webdriver.Firefox(executable_path = 'geckodriver.exe')
driver
# Out:
# <selenium.webdriver.firefox.webdriver.WebDriver (session="6a9a9aad-62ff-468e-aa3a-4fbba92ce020")>

# %%
driver.get('https://www.codingninjas.com/')

# %%
driver.current_url
# Out:
# 'https://www.codingninjas.com/'

# %% [markdown]
# driver.refresh()

# %%
driver.get('https://www.kaggle.com/')

# %%
datasets_click = driver.find_element_by_link_text('Datasets')
datasets_click.click()

# %%
driver.current_url
# Out:
# 'https://www.kaggle.com/datasets'

# %%
driver.current_window_handle
# Out:
# '5c8d503b-7aea-48c0-b3f5-9e3b7a180f66'

# %%
driver.quit()

# %%
driver = webdriver.Firefox(executable_path='geckodriver.exe')
driver
# Out:
# <selenium.webdriver.firefox.webdriver.WebDriver (session="4af11c2c-a591-41fe-a169-d0392d8b7290")>

# %%
driver.get('https://www.kaggle.com/')

# %%
driver.close()

# %%
driver = webdriver.Firefox(executable_path='geckodriver.exe')
driver.get('https://www.kaggle.com/')

# %%
competitions = driver.find_element_by_partial_link_text('Comp')
competitions.click()

# %%
driver.maximize_window()

# %%
home = driver.find_element_by_partial_link_text('Home')
home.click()

# %%
discussions = driver.find_element_by_class_name('iEqsac')
discussions.click()

# %%
driver.back()

# %%
img_tag = driver.find_element_by_tag_name('img')
img_tag
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="345425d1-8548-4f05-b6af-b59a79f291c4")>

# %%
h1_tags = driver.find_elements_by_tag_name('h1')
h1_tags
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="728cd826-9207-492d-a909-d3af598acf79")>]

# %%
img_tags = driver.find_elements_by_tag_name('img')
img_tags
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="345425d1-8548-4f05-b6af-b59a79f291c4")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="0fc7a069-2cab-42c5-9d54-d33b371ac8fc")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="bd2e3a6f-ad2c-42de-9d52-3ec2170b8bf0")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="ee53d4c5-3a44-4154-b8b3-06909950f78a")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="f01fcf7b-5e70-4160-aa91-eed40e1de21c")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="4b95f824-05af-40e6-91ba-9390a5ebe3c6")>,
# ...

# %%
robots = driver.find_element_by_name('robots')
robots.text
# Out:
# ''

# %%
description = driver.find_element_by_name('description')
description
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="a5c2149f-3c49-4ef9-b88f-a31cf5ce67bf")>

# %%
div_selectors = driver.find_elements_by_css_selector('div')
div_selectors
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="722d7cc5-c5ad-483c-b541-dc1e3f508a0a")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="04ded9c0-9dc3-47fe-86b2-a3d8864e658f")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="3f7d1b9e-1642-4433-ba42-2aee4d9a89ae")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="c3d2cecc-b63f-4ab3-b8c0-44d76aa7fe20")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="f33343f8-6cd1-444e-a59b-8859e83cbf1d")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="cd6f0575-8b02-4a05-95a9-5198d01fa053")>,
# ...

# %%
site_body = driver.find_element_by_id('site-body')
site_body
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="bb187af5-ae2c-4fd5-906e-73690c919818")>

# %%
site_bodies = driver.find_elements_by_id('site-body')
site_bodies
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="bb187af5-ae2c-4fd5-906e-73690c919818")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="365209e9-7891-4b21-a67d-75ad15e952d8", element="114a971f-caaa-4d91-a9e8-c5c5f987d34c")>]

# %%
img_tag.text
# Out:
# ''

# %%
img_tag.get_attribute('class')
# Out:
# 'sc-jlZJtj QgNfY'

# %%
img_tag.get_attribute('href')

# %%
img_tag.get_attribute('id')
# Out:
# ''

# %%
site_body.text
# Out:
# ''

# %%
site_body.get_attribute('id')
# Out:
# 'site-body'

# %%
site_body.tag_name
# Out:
# 'div'

# %%
img_tag.tag_name
# Out:
# 'img'

# %%
description.tag_name
# Out:
# 'meta'

# %%
description.get_attribute('id')
# Out:
# ''

# %%
description.get_attribute('class')
# Out:
# ''

# %%
description.text
# Out:
# ''

# %%
driver.close()

# %%
base_url = 'https://www.openthebooks.com/kansas-state-employees/'
driver = webdriver.Firefox(executable_path='geckodriver.exe')
driver.get(base_url)

# %%
driver.quit()

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
# for i in range(2):
driver = webdriver.Firefox(executable_path='geckodriver.exe')
driver.get(base_url + "?pg=" + str(1))
data = driver.page_source
emp_table = driver.find_elements_by_tag_name('th')

# %%
header_column = []
for x in emp_table:
    header_column.append(x.text)

# %%
driver = webdriver.Firefox(executable_path='geckodriver.exe')
driver.get('https://books.toscrape.com/')

# %%
ans = driver.find_element_by_xpath('/html/head/title')

# %%
ans.get_attribute('outerHTML')
# Out:
# '<title>\n    All products | Books to Scrape - Sandbox\n</title>'

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n    All products | Books to Scrape - Sandbox\n'

# %%
emp_table = driver.find_elements_by_tag_name('td')
records = []
for x in emp_table:
    records.append(x.text)

# %%
rows = []
for i in range(0,len(records),6):
    rows.append(records[i:i+6])
rows
# Out:
# [['2020',
#   'University of Kansas',
#   'Long Jeffrey Paul',
#   'Director Major Division/School',
#   '$1,476,923.14',
#   'Kansas Department of Administration'],
#  ['2019',
#   'University of Kansas',
#   'Long Jeffrey Paul',
#   'Director Major Division/School',
#   '$1,315,384.67',
#   'Kansas Department of Administration'],
#  ['2020',
#   'Wichita State University',
#   'Tomblin John S',
#   'Exec Dir Niar Sr Vp Industry/Defense Programs',
#   '$901,160.02',
#   'Kansas Department of Administration'],
#  ['2019',
#   'University of Kansas Medical Center (KUMC) - KC',
#   'Simari Robert D',
#   'Executive Vice Chancellor',
#   '$688,300.08',
#   'Kansas Department of Administration'],
#  ['2020',
#   'University of Kansas Medical Center (KUMC) - KC',
#   'Simari Robert D',
#   'Executive Vice Chancellor',
#   '$688,300.08',
#   'Kansas Department of Administration'],
#  ['2020',
#   'University of Kansas',
#   'Girod Doug A',
#   'Chancellor',
#   '$653,269.24',
# ...

# %%
rows = []
for i in range(100):
    driver = webdriver.Firefox(executable_path='geckodriver.exe')
    driver.get(base_url + "?pg=" + str(i+1))
    emp_table = driver.find_elements_by_tag_name('td')
    records = []
    for x in emp_table:
        records.append(x.text)
    for i in range(0,len(records),6):
        rows.append(records[i:i+6])
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-177-9d0c102d3dbd> in <module>
#       1 rows = []
#       2 for i in range(100):
# ----> 3     driver = webdriver.Firefox(executable_path='geckodriver.exe')
#       4     driver.get(base_url + "?pg=" + str(i+1))
#       5     emp_table = driver.find_elements_by_tag_name('td')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\firefox\webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, options, service_log_path, firefox_options, service_args, desired_capabilities, log_path, keep_alive)
#     168             executor = FirefoxRemoteConnection(
#     169                 remote_server_addr=self.service.service_url)
# --> 170             RemoteWebDriver.__init__(
#     171                 self,
#     172                 command_executor=executor,
#
# ...

# %%
rows
# Out:
# [['2020',
#   'University of Kansas',
#   'Long Jeffrey Paul',
#   'Director Major Division/School',
#   '$1,476,923.14',
#   'Kansas Department of Administration'],
#  ['2019',
#   'University of Kansas',
#   'Long Jeffrey Paul',
#   'Director Major Division/School',
#   '$1,315,384.67',
#   'Kansas Department of Administration'],
#  ['2020',
#   'Wichita State University',
#   'Tomblin John S',
#   'Exec Dir Niar Sr Vp Industry/Defense Programs',
#   '$901,160.02',
#   'Kansas Department of Administration'],
#  ['2019',
#   'University of Kansas Medical Center (KUMC) - KC',
#   'Simari Robert D',
#   'Executive Vice Chancellor',
#   '$688,300.08',
#   'Kansas Department of Administration'],
#  ['2020',
#   'University of Kansas Medical Center (KUMC) - KC',
#   'Simari Robert D',
#   'Executive Vice Chancellor',
#   '$688,300.08',
#   'Kansas Department of Administration'],
#  ['2020',
#   'University of Kansas',
#   'Girod Doug A',
#   'Chancellor',
#   '$653,269.24',
# ...

# %%
len(rows)
# Out:
# 1700

# %%
for i in range(19,39):
    driver = webdriver.Firefox(executable_path='geckodriver.exe')
    driver.get(base_url + "?pg=" + str(i+1))
    emp_table = driver.find_elements_by_tag_name('td')
    records = []
    for x in emp_table:
        records.append(x.text)
    for i in range(0,len(records),6):
        rows.append(records[i:i+6])

# %%
driver = webdriver.Firefox(executable_path='geckodriver.exe')
driver.get(base_url + "?pg=19")
emp_table = driver.find_elements_by_tag_name('td')
records = []
for x in emp_table:
    records.append(x.text)
for i in range(0,len(records),6):
    rows.append(records[i:i+6])

# %%
for i in range(40,60):
    driver = webdriver.Firefox(executable_path='geckodriver.exe')
    driver.get(base_url + "?pg=" + str(i+1))
    emp_table = driver.find_elements_by_tag_name('td')
    records = []
    for x in emp_table:
        records.append(x.text)
    for i in range(0,len(records),6):
        rows.append(records[i:i+6])

# %%
for i in range(61,81):
    driver = webdriver.Firefox(executable_path='geckodriver.exe')
    driver.get(base_url + "?pg=" + str(i+1))
    emp_table = driver.find_elements_by_tag_name('td')
    records = []
    for x in emp_table:
        records.append(x.text)
    for i in range(0,len(records),6):
        rows.append(records[i:i+6])

# %%
for i in range(82,99):
    driver = webdriver.Firefox(executable_path='geckodriver.exe')
    driver.get(base_url + "?pg=" + str(i+1))
    emp_table = driver.find_elements_by_tag_name('td')
    records = []
    for x in emp_table:
        records.append(x.text)
    for i in range(0,len(records),6):
        rows.append(records[i:i+6])
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-184-0b8be760a095> in <module>
#       1 for i in range(82,99):
# ----> 2     driver = webdriver.Firefox(executable_path='geckodriver.exe')
#       3     driver.get(base_url + "?pg=" + str(i+1))
#       4     emp_table = driver.find_elements_by_tag_name('td')
#       5     records = []
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\firefox\webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, options, service_log_path, firefox_options, service_args, desired_capabilities, log_path, keep_alive)
#     168             executor = FirefoxRemoteConnection(
#     169                 remote_server_addr=self.service.service_url)
# --> 170             RemoteWebDriver.__init__(
#     171                 self,
#     172                 command_executor=executor,
#
# ...

# %%
for i in range(98,99):
    driver = webdriver.Firefox(executable_path='geckodriver.exe')
    driver.get(base_url + "?pg=" + str(i+1))
    emp_table = driver.find_elements_by_tag_name('td')
    records = []
    for x in emp_table:
        records.append(x.text)
    for i in range(0,len(records),6):
        rows.append(records[i:i+6])

# %%
len(rows)
# Out:
# 7900

# %%
df = pd.DataFrame(rows)
df.columns = header_column
df
# Out:
#       Year                                         Employer  \
# 0     2020                             University of Kansas
# 1     2019                             University of Kansas
# 2     2020                         Wichita State University
# 3     2019  University of Kansas Medical Center (KUMC) - KC
# 4     2020  University of Kansas Medical Center (KUMC) - KC
# ...    ...                                              ...
# 7895  2018                            Kansas Highway Patrol
# 7896  2017                             University of Kansas
# 7897  2020                             University of Kansas
# 7898  2020                    Kansas State University (KSU)
# 7899  2019    Kansas Commission on Veterans' Affairs Office
#
#                           Name                                          Title  \
# 0            Long Jeffrey Paul                 Director Major Division/School
# 1            Long Jeffrey Paul                 Director Major Division/School
# ...

# %%
df.to_excel('Kansas State Employee Salaries.xlsx')

# %%
from selenium import webdriver

# %%
driver = webdriver.Firefox(executable_path='geckodriver.exe')
driver
# Out:
# <selenium.webdriver.firefox.webdriver.WebDriver (session="e6f05528-3721-413a-8ae8-e71945dce407")>

# %%
driver.get('https://books.toscrape.com/')

# %%
ans = driver.find_element_by_xpath('/html/head/title')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="3e1cd0fa-b18d-4433-98ff-8460da37027d")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<title>\n    All products | Books to Scrape - Sandbox\n</title>'

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n    All products | Books to Scrape - Sandbox\n'

# %%
ans = driver.find_element_by_xpath('/html/body/div/div/ul')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="d789fc4f-5251-48d9-b6bf-1f746e31968f")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<ul class="breadcrumb">\n        <li>\n            <a href="index.html">Home</a>\n        </li>\n        <li class="active">All products</li>\n    </ul>'

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n        <li>\n            <a href="index.html">Home</a>\n        </li>\n        <li class="active">All products</li>\n    '

# %%
ans = driver.find_element_by_xpath('/html/body/header/div/div/div/small')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="25be0b97-35bc-462b-8304-7bccd24b53a1")>

# %%
ans.get_attribute('innerHTML')
# Out:
# ' We love being scraped!'

# %%
ans = driver.find_element_by_xpath('/html/body/header/div/div/div/a')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="c74f10c7-7d4a-49cb-b338-1d42d443976a")>

# %%
ans.get_attribute('innerHTML')
# Out:
# 'Books to Scrape'

# %%
ans = driver.find_element_by_xpath('/html/body/div/div/div/aside/div[@class="side_categories"]')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="00b72850-ff76-458a-aa45-5ca48c7dd436")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<div class="side_categories">\n            <ul class="nav nav-list">\n                \n                    <li>\n                        <a href="catalogue/category/books_1/index.html">\n                            \n                                Books\n                            \n                        </a>\n\n                        <ul>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/mystery_3/index.html">\n                            \n                                Mystery\n                            \n                        </a>\n\n                        </li>\n                  
# ...

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n            <ul class="nav nav-list">\n                \n                    <li>\n                        <a href="catalogue/category/books_1/index.html">\n                            \n                                Books\n                            \n                        </a>\n\n                        <ul>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/mystery_3/index.html">\n                            \n                                Mystery\n                            \n                        </a>\n\n                        </li>\n                        \n                \n   
# ...

# %%
ans = driver.find_element_by_xpath('/html/body/div/div/div/aside/div/ul/li')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="9e081827-4181-4670-8d72-ba71d1e85ed5")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<li>\n                        <a href="catalogue/category/books_1/index.html">\n                            \n                                Books\n                            \n                        </a>\n\n                        <ul>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/mystery_3/index.html">\n                            \n                                Mystery\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/book
# ...

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n                        <a href="catalogue/category/books_1/index.html">\n                            \n                                Books\n                            \n                        </a>\n\n                        <ul>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/mystery_3/index.html">\n                            \n                                Mystery\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/hi
# ...

# %%
ans = driver.find_element_by_xpath('/html/body/div/div/div/aside/div/ul/li/a')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="6c340c84-da44-417e-becf-d384d3f8469d")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n                            \n                                Books\n                            \n                        '

# %%
ans = driver.find_element_by_xpath('/html/body/div/div/div/aside/div[@class="side_categories"]/ul/li/ul/li')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="b3b70d1d-dfb7-47f0-a54a-03367a997912")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        '

# %%
ans = driver.find_elements_by_xpath('/html/body/div/div/div/aside/div[@class="side_categories"]/ul/li/ul/li')
ans
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="b3b70d1d-dfb7-47f0-a54a-03367a997912")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="89252f79-f144-48c0-96a3-6d814ad98297")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="d74d5629-ac30-4670-9f8b-34511062c5de")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="f23493c5-e2fe-47a7-9383-bd1623e681ff")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="18909684-d819-4139-842f-47f6f66712b9")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="2c38b6cb-3ec7-4cc2-a64f-8982d7c3b668")>,
# ...

# %%
ans = driver.find_element_by_xpath('//ul/li')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="ceccf340-c821-4ea2-b171-7e9ce267c751")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n            <a href="index.html">Home</a>\n        '

# %%
ans = driver.find_element_by_xpath('//div[@class="side_categories"]')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="00b72850-ff76-458a-aa45-5ca48c7dd436")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<div class="side_categories">\n            <ul class="nav nav-list">\n                \n                    <li>\n                        <a href="catalogue/category/books_1/index.html">\n                            \n                                Books\n                            \n                        </a>\n\n                        <ul>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/mystery_3/index.html">\n                            \n                                Mystery\n                            \n                        </a>\n\n                        </li>\n                  
# ...

# %%
ans = driver.find_element_by_xpath('//form[@class="form-horizontal"]')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="87d0ff84-5321-468c-a13b-0d160df1d622")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n        \n        <div style="display:none">\n            \n            \n        </div>\n\n        \n            \n                \n                    <strong>1000</strong> results - showing <strong>1</strong> to <strong>20</strong>.\n                \n            \n            \n        \n    '

# %%
ans = driver.find_element_by_xpath('/html/body//aside')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="453cea83-f3b3-4638-b06c-5e9be79d54a9")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n                \n                <div id="promotions_left">\n                    \n                </div>\n                \n    \n    \n        \n        <div class="side_categories">\n            <ul class="nav nav-list">\n                \n                    <li>\n                        <a href="catalogue/category/books_1/index.html">\n                            \n                                Books\n                            \n                        </a>\n\n                        <ul>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/mystery_3/index.html">\n                        
# ...

# %%
ans = driver.find_elements_by_xpath('/html/body/div//a')
ans
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="2d519711-2440-4b8e-9a2d-c05d05b3d3a2")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="6c340c84-da44-417e-becf-d384d3f8469d")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="e1440892-3107-427d-af9e-cb21280551c8")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="dfea5f80-3f0c-43de-9dfd-099cc4a386eb")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="bc01a623-e49d-4b6d-ae26-9440f6b081c3")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="aa93ce37-e024-4acc-bdf0-1732a12086ab")>,
# ...

# %%
ans = driver.find_element_by_xpath('/html/body/div//div[@id="messages"]')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="3deac219-b5ee-45d0-abe5-9a6d240e2b1d")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<div id="messages">\n\n</div>'

# %%
ans = driver.find_element_by_xpath('//*')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="afa1309a-2934-4aa5-9719-64d571eb7dee")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '<!--<![endif]--><head>\n        <title>\n    All products | Books to Scrape - Sandbox\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n        <meta name="created" content="24th Jun 2016 09:29">\n        <meta name="description" content="">\n        <meta name="viewport" content="width=device-width">\n        <meta name="robots" content="NOARCHIVE,NOCACHE">\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="shortcut icon" href="static/oscar/favicon.ico">\n        \n\n        \n        \n    \n    \n        <link rel="stylesheet" type="text/css" href="static/oscar/css/styles.css">\n    \n    <link rel="stylesheet" href="static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.css">\n    <link rel="stylesheet" type="text/css" href="static/oscar/css/datetim
# ...

# %%
ans = driver.find_element_by_xpath('/div[@class="col-sm-8 h1"]')
ans
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-51-774c4846075d> in <module>
# ----> 1 ans = driver.find_element_by_xpath('/div[@class="col-sm-8 h1"]')
#       2 ans
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ...

# %%
ans = driver.find_element_by_xpath('//div[contains(@class,"h1")]')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="7e2a6ecb-c805-4ed0-8038-c1159e203d02")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a><small> We love being scraped!</small>\n</div>'

# %%
ans = driver.find_element_by_xpath('//div[starts-with(@class,"col")]')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="7e2a6ecb-c805-4ed0-8038-c1159e203d02")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a><small> We love being scraped!</small>\n</div>'

# %%
ans = driver.find_element_by_xpath('//ul[contains(@class,"nav")]')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="2938b764-b3c7-4b26-839b-91ae2c69545e")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<ul class="nav nav-list">\n                \n                    <li>\n                        <a href="catalogue/category/books_1/index.html">\n                            \n                                Books\n                            \n                        </a>\n\n                        <ul>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/mystery_3/index.html">\n                            \n                                Mystery\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                 
# ...

# %%
ans = driver.find_element_by_xpath('//ul[starts-with(@class,"nav")]/li/ul/li')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="b3b70d1d-dfb7-47f0-a54a-03367a997912")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        '

# %%
ans = driver.find_element_by_xpath('//ul[starts-with(@class,"nav")]/li/ul/li[4]')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="f23493c5-e2fe-47a7-9383-bd1623e681ff")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n                        <a href="catalogue/category/books/sequential-art_5/index.html">\n                            \n                                Sequential Art\n                            \n                        </a>\n\n                        '

# %%
ans = driver.find_elements_by_xpath('//ul[starts-with(@class,"nav")]/li/ul/li[position()<5]')
ans
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="b3b70d1d-dfb7-47f0-a54a-03367a997912")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="89252f79-f144-48c0-96a3-6d814ad98297")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="d74d5629-ac30-4670-9f8b-34511062c5de")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="f23493c5-e2fe-47a7-9383-bd1623e681ff")>]

# %%
ans = driver.find_element_by_xpath('//ul[starts-with(@class,"nav")]/li/ul/li[last()]')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="9b62b612-93a6-4920-9e1e-b5597ce3aa42")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n                        <a href="catalogue/category/books/crime_51/index.html">\n                            \n                                Crime\n                            \n                        </a>\n\n                        '

# %%
ans = driver.find_element_by_xpath('//ul[starts-with(@class,"nav")]/li/ul/li[9]')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="7499aaaa-542d-4825-9796-9fb41a523cf4")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<li>\n                        <a href="catalogue/category/books/fiction_10/index.html">\n                            \n                                Fiction\n                            \n                        </a>\n\n                        </li>'

# %%
ans = driver.find_element_by_css_selector('html head title')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="3e1cd0fa-b18d-4433-98ff-8460da37027d")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n    All products | Books to Scrape - Sandbox\n'

# %%
ans.get_attribute('outerHTML')
# Out:
# '<title>\n    All products | Books to Scrape - Sandbox\n</title>'

# %%
ans = driver.find_element_by_css_selector('div.page_inner')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="0fa689dc-1ddd-4196-8398-6eb5296a0fd0")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n            <div class="row">\n                <div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a><small> We love being scraped!</small>\n</div>\n\n                \n            </div>\n        '

# %%
ans = driver.find_element_by_css_selector('div.page_inner ul li')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="ceccf340-c821-4ea2-b171-7e9ce267c751")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<li>\n            <a href="index.html">Home</a>\n        </li>'

# %%
ans = driver.find_element_by_css_selector('div.page_inner>ul>li')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="ceccf340-c821-4ea2-b171-7e9ce267c751")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<li>\n            <a href="index.html">Home</a>\n        </li>'

# %%
ans = driver.find_element_by_css_selector('ul.breadcrumb')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="d789fc4f-5251-48d9-b6bf-1f746e31968f")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n        <li>\n            <a href="index.html">Home</a>\n        </li>\n        <li class="active">All products</li>\n    '

# %%
ans = driver.find_elements_by_css_selector('ul.breadcrumb li')
ans
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="ceccf340-c821-4ea2-b171-7e9ce267c751")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="2e8b9bf9-f214-49f6-a792-cc9393087ff6")>]

# %%
ans = driver.find_element_by_css_selector('div.side_categories')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="00b72850-ff76-458a-aa45-5ca48c7dd436")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n            <ul class="nav nav-list">\n                \n                    <li>\n                        <a href="catalogue/category/books_1/index.html">\n                            \n                                Books\n                            \n                        </a>\n\n                        <ul>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/mystery_3/index.html">\n                            \n                                Mystery\n                            \n                        </a>\n\n                        </li>\n                        \n                \n   
# ...

# %%
ans = driver.find_elements_by_css_selector('div.side_categories ul li ul li')
ans
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="b3b70d1d-dfb7-47f0-a54a-03367a997912")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="89252f79-f144-48c0-96a3-6d814ad98297")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="d74d5629-ac30-4670-9f8b-34511062c5de")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="f23493c5-e2fe-47a7-9383-bd1623e681ff")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="18909684-d819-4139-842f-47f6f66712b9")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="2c38b6cb-3ec7-4cc2-a64f-8982d7c3b668")>,
# ...

# %%
ans = driver.find_elements_by_css_selector('div.side_categories ul li ul li a')
ans
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="e1440892-3107-427d-af9e-cb21280551c8")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="dfea5f80-3f0c-43de-9dfd-099cc4a386eb")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="bc01a623-e49d-4b6d-ae26-9440f6b081c3")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="aa93ce37-e024-4acc-bdf0-1732a12086ab")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="e919d37c-c35b-40aa-adf1-38bb4275614b")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="42c53dbb-f90f-40a0-8488-83a48f86668d")>,
# ...

# %%
ans = driver.find_elements_by_css_selector('form.form-horizontal strong')
ans
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="13bf2104-44c1-4d28-a0de-f68f605d5539")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="7355bdd1-155d-4faf-9e88-ab6df27abcbe")>,
#  <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="05036e75-6dc4-469b-8e3d-a31e872f3a77")>]

# %%
ans = driver.find_element_by_css_selector('div.alert')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="2072837f-55bd-47f7-8165-0601518b02b1")>

# %%
ans.get_attribute('innerHTML')
# Out:
# '<strong>Warning!</strong> This is a demo website for web scraping purposes. Prices and ratings here were randomly assigned and have no real meaning.'

# %%
ans = driver.find_element_by_css_selector('ol.row')
ans
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="52aa07c4-6822-459b-bee4-653c5321e7b2")>

# %%
ans.get_attribute('outerHTML')
# Out:
# '<ol class="row">\n                    \n                        <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">\n\n\n\n\n\n\n    <article class="product_pod">\n        \n            <div class="image_container">\n                \n                    \n                    <a href="catalogue/a-light-in-the-attic_1000/index.html"><img src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg" alt="A Light in the Attic" class="thumbnail"></a>\n                    \n                \n            </div>\n        \n\n        \n            \n                <p class="star-rating Three">\n                    <i class="icon-star"></i>\n                    <i class="icon-star"></i>\n                    <i class="icon-star"></i>\n                    <i class="icon-star"></i>\n                    <i class="icon-star"></i>\n                </p>\n            \n        \n\n        \n            <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in 
# ...

# %%
ans = driver.find_elements_by_css_selector('ol.row li')
for x in ans:
    print(x.get_attribute('innerHTML'))
# Out:
#     <article class="product_pod">
#
#             <div class="image_container">
#
#
#                     <a href="catalogue/a-light-in-the-attic_1000/index.html"><img src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg" alt="A Light in the Attic" class="thumbnail"></a>
#
#
#             </div>
#
#
#
#
#                 <p class="star-rating Three">
#                     <i class="icon-star"></i>
#                     <i class="icon-star"></i>
#                     <i class="icon-star"></i>
#                     <i class="icon-star"></i>
#                     <i class="icon-star"></i>
#                 </p>
#
#
#
#
#             <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
#
#
#
#             <div class="product_price">
#
#
#
#
#
#
#
#
#         <p class="price_color">£51.77</p>
#
#
# <p class="instock availability">
#     <i class="icon-ok"></i>
#
#         In stock
#
# </p>
#
#
#
#
#
#
#
#
#
#
# ...

# %%
driver.get('https://www.google.com/')

# %%
text_box = driver.find_element_by_name('q')
text_box
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="b35a3049-d672-4503-85df-560b972c34fc")>

# %%
text_box.send_keys("selenium")

# %%
text_box.submit()

# %%
driver.back()

# %%
text_box.is_displayed
# Out:
# <bound method WebElement.is_displayed of <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="b35a3049-d672-4503-85df-560b972c34fc")>>

# %%
driver.get('https://www.google.com/maps')

# %%
location = driver.find_element_by_name('q')
location
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="8ff27a11-435d-4230-83df-4c3988c6b8d0")>

# %%
location.send_keys('Toronto, Ontario')

# %%
location.submit()

# %%
driver.get('https://www.amazon.in/')

# %%
search_box = driver.find_element_by_name('field-keywords')
search_box
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="700c1013-9b6c-4856-9b60-c74cb43487ae")>

# %%
search_box.send_keys('Gaming Laptops')

# %%
search_box.submit()

# %%
driver.get('https://www.google.com/maps/')

# %%
search = driver.find_element_by_class_name('nhb85d-BIqFsb')
search
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="931a536b-4b43-45f3-b846-0a75f46aa1ba")>

# %%
text_box = driver.find_element_by_name('q')
text_box.send_keys("Toronto, Ontario, Canada")
search.click()

# %%
driver.get('https://mail.google.com/mail/u/0/')

# %%
sign_in = driver.find_element_by_xpath('/html/body/header//div[@class="header__aside__buttons"]/a[2]')
sign_in
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="72440df7-079c-4c07-973e-149ce09e49bf")>

# %%
sign_in.get_attribute('innerHTML')
# Out:
# 'Sign in'

# %%
sign_in.click()

# %%
email_id = driver.find_element_by_id('identifierId')
email_id
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="e6f05528-3721-413a-8ae8-e71945dce407", element="8b0da9ed-2f0d-4e77-b537-ce8c71996ae7")>

# %%
email_id.send_keys("sayamk565@gmail.com")

# %%
email_id.submit()

# %%
next_button = driver.find_element_by_class_name('VfPpkd-vQzf8d')
next_button.click()

# %%
driver.get('https://www.facebook.com/')

# %%
email_id = driver.find_element_by_name('email')
email_id.send_keys("")
password = driver.find_element_by_name('pass')
password.send_keys("")

# %%
login_button = driver.find_element_by_name('login')
login_button.submit()
